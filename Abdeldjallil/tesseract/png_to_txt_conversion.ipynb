# %% [markdown]
# # Text Extraction from scanned pdf file using OCR

# %% [markdown]
# ## spliting the images to parts
# when searching i found out that tessaract will perform better on small chancks of text, this is why i choose to split the data into chuncks

# %%
import os
import cv2
from PIL import Image
import pytesseract
from pytesseract import Output
import numpy as np

def split_image_with_ocr(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    for filename in os.listdir(input_folder):
        if filename.endswith('.png') or filename.endswith('.jpg'):
            input_image = os.path.join(input_folder, filename)

            # Read the image using OpenCV
            img = cv2.imread(input_image)

            if img is None:
                print(f"Failed to load {filename}")
                continue

            # Convert the image to RGB format (OpenCV loads images in BGR format)
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Convert the NumPy array (OpenCV image) to a PIL Image
            pil_img = Image.fromarray(img_rgb)

            # Perform OCR on the image to get bounding boxes for the text
            data = pytesseract.image_to_data(pil_img, output_type=Output.DICT)

            # Extract the y-coordinates (top positions) and heights of each text box
            heights = data['top']
            text_heights = data['height']

            # Sort the y-coordinates of the text boxes
            heights_sorted = sorted(heights)

            # Calculate split points based on gaps between text boxes
            split_gap = 20  # Adjust this depending on the size of gaps in your images

            # Identify two split points based on the largest gaps between text boxes
            split_points = []
            for i in range(len(heights_sorted) - 1):
                gap = heights_sorted[i + 1] - (heights_sorted[i] + text_heights[i])
                if gap > split_gap:
                    split_points.append(heights_sorted[i + 1])
                if len(split_points) == 2:  # We only need two split points
                    break

            # If we couldn't find enough split points, skip this image
            if len(split_points) < 2:
                print(f"Error: Could not find enough split points for {filename}.")
                continue

            # Split the image into three parts
            top_part = img[:split_points[0], :]
            middle_part = img[split_points[0]:split_points[1], :]
            bottom_part = img[split_points[1]:, :]

            # Check if any of the parts are empty
            if top_part.size == 0 or middle_part.size == 0 or bottom_part.size == 0:
                print(f"Error: Image {filename} split failed, empty part found.")
                continue

            # Create output filenames
            base_filename = os.path.splitext(filename)[0]
            output_top = os.path.join(output_folder, f'{base_filename}_top.png')
            output_middle = os.path.join(output_folder, f'{base_filename}_middle.png')
            output_bottom = os.path.join(output_folder, f'{base_filename}_bottom.png')

            # Save the three parts as separate images
            cv2.imwrite(output_top, top_part)
            cv2.imwrite(output_middle, middle_part)
            cv2.imwrite(output_bottom, bottom_part)

            print(f"Image {filename} split and saved as {output_top}, {output_middle}, and {output_bottom}.")

# Example usage
input_folder = 'images'
output_folder = 'split_images'
split_image_with_ocr(input_folder, output_folder)
# Out:
# Image short_story-003.png split and saved as split_images\short_story-003_top.png, split_images\short_story-003_middle.png, and split_images\short_story-003_bottom.png.
# Image short_story-004.png split and saved as split_images\short_story-004_top.png, split_images\short_story-004_middle.png, and split_images\short_story-004_bottom.png.
# Image short_story-005.png split and saved as split_images\short_story-005_top.png, split_images\short_story-005_middle.png, and split_images\short_story-005_bottom.png.
# Image short_story-006.png split and saved as split_images\short_story-006_top.png, split_images\short_story-006_middle.png, and split_images\short_story-006_bottom.png.
# Image short_story-007.png split and saved as split_images\short_story-007_top.png, split_images\short_story-007_middle.png, and split_images\short_story-007_bottom.png.
# Image short_story-008.png split and saved as split_images\short_story-008_top.png, split_images\short_story-008_middle.png, and split_images\short_story-008_bottom.png.
# Image short_story-009.png split and saved as split_images\short_story-009_top.png, split_images\short_story-009_middle.png, and split_images\short_story-009_bottom.png.
# Image short_story-010.png split and saved as split_images\short_story-010_top.png, split_images\short_story-010_middle.png, and split_images\short_story-010_bottom.png.
# Image short_story-011.png split and saved as split_images\short_story-011_top.png, split_images\short_story-011_middle.png, and split_images\short_story-011_bottom.png.
# Image short_story-012.png split and saved as split_images\short_story-012_top.png, split_images\short_story-012_middle.png, and split_images\short_story-012_bottom.png.
# Image short_story-013.png split and saved as split_images\short_story-013_top.png, split_images\short_story-013_middle.png, and split_images\short_story-013_bottom.png.
# Image short_story-014.png split and saved as split_images\short_story-014_top.png, split_images\short_story-014_middle.png, and split_images\short_story-014_bottom.png.
# Image short_story-015.png split and saved as split_images\short_story-015_top.png, split_images\short_story-015_middle.png, and split_images\short_story-015_bottom.png.
# Image short_story-016.png split and saved as split_images\short_story-016_top.png, split_images\short_story-016_middle.png, and split_images\short_story-016_bottom.png.
# Image short_story-017.png split and saved as split_images\short_story-017_top.png, split_images\short_story-017_middle.png, and split_images\short_story-017_bottom.png.
# Image short_story-018.png split and saved as split_images\short_story-018_top.png, split_images\short_story-018_middle.png, and split_images\short_story-018_bottom.png.
# Image short_story-019.png split and saved as split_images\short_story-019_top.png, split_images\short_story-019_middle.png, and split_images\short_story-019_bottom.png.
# Image short_story-020.png split and saved as split_images\short_story-020_top.png, split_images\short_story-020_middle.png, and split_images\short_story-020_bottom.png.
# Image short_story-021.png split and saved as split_images\short_story-021_top.png, split_images\short_story-021_middle.png, and split_images\short_story-021_bottom.png.
# Image short_story-022.png split and saved as split_images\short_story-022_top.png, split_images\short_story-022_middle.png, and split_images\short_story-022_bottom.png.
# Image short_story-023.png split and saved as split_images\short_story-023_top.png, split_images\short_story-023_middle.png, and split_images\short_story-023_bottom.png.
# Image short_story-024.png split and saved as split_images\short_story-024_top.png, split_images\short_story-024_middle.png, and split_images\short_story-024_bottom.png.
# Image short_story-025.png split and saved as split_images\short_story-025_top.png, split_images\short_story-025_middle.png, and split_images\short_story-025_bottom.png.
# Image short_story-026.png split and saved as split_images\short_story-026_top.png, split_images\short_story-026_middle.png, and split_images\short_story-026_bottom.png.
# Image short_story-027.png split and saved as split_images\short_story-027_top.png, split_images\short_story-027_middle.png, and split_images\short_story-027_bottom.png.
# Image short_story-028.png split and saved as split_images\short_story-028_top.png, split_images\short_story-028_middle.png, and split_images\short_story-028_bottom.png.
# Image short_story-029.png split and saved as split_images\short_story-029_top.png, split_images\short_story-029_middle.png, and split_images\short_story-029_bottom.png.
# Image short_story-030.png split and saved as split_images\short_story-030_top.png, split_images\short_story-030_middle.png, and split_images\short_story-030_bottom.png.
# Image short_story-031.png split and saved as split_images\short_story-031_top.png, split_images\short_story-031_middle.png, and split_images\short_story-031_bottom.png.
# Image short_story-032.png split and saved as split_images\short_story-032_top.png, split_images\short_story-032_middle.png, and split_images\short_story-032_bottom.png.
# Image short_story-033.png split and saved as split_images\short_story-033_top.png, split_images\short_story-033_middle.png, and split_images\short_story-033_bottom.png.
# Image short_story-034.png split and saved as split_images\short_story-034_top.png, split_images\short_story-034_middle.png, and split_images\short_story-034_bottom.png.
# Image short_story-035.png split and saved as split_images\short_story-035_top.png, split_images\short_story-035_middle.png, and split_images\short_story-035_bottom.png.
# Image short_story-036.png split and saved as split_images\short_story-036_top.png, split_images\short_story-036_middle.png, and split_images\short_story-036_bottom.png.
# Image short_story-037.png split and saved as split_images\short_story-037_top.png, split_images\short_story-037_middle.png, and split_images\short_story-037_bottom.png.
# Image short_story-038.png split and saved as split_images\short_story-038_top.png, split_images\short_story-038_middle.png, and split_images\short_story-038_bottom.png.
# Image short_story-039.png split and saved as split_images\short_story-039_top.png, split_images\short_story-039_middle.png, and split_images\short_story-039_bottom.png.
# Image short_story-040.png split and saved as split_images\short_story-040_top.png, split_images\short_story-040_middle.png, and split_images\short_story-040_bottom.png.
# Image short_story-041.png split and saved as split_images\short_story-041_top.png, split_images\short_story-041_middle.png, and split_images\short_story-041_bottom.png.
# Image short_story-042.png split and saved as split_images\short_story-042_top.png, split_images\short_story-042_middle.png, and split_images\short_story-042_bottom.png.
# Image short_story-043.png split and saved as split_images\short_story-043_top.png, split_images\short_story-043_middle.png, and split_images\short_story-043_bottom.png.
# Image short_story-044.png split and saved as split_images\short_story-044_top.png, split_images\short_story-044_middle.png, and split_images\short_story-044_bottom.png.
# Image short_story-045.png split and saved as split_images\short_story-045_top.png, split_images\short_story-045_middle.png, and split_images\short_story-045_bottom.png.
# Image short_story-046.png split and saved as split_images\short_story-046_top.png, split_images\short_story-046_middle.png, and split_images\short_story-046_bottom.png.
# Image short_story-047.png split and saved as split_images\short_story-047_top.png, split_images\short_story-047_middle.png, and split_images\short_story-047_bottom.png.
# Image short_story-048.png split and saved as split_images\short_story-048_top.png, split_images\short_story-048_middle.png, and split_images\short_story-048_bottom.png.
# Image short_story-049.png split and saved as split_images\short_story-049_top.png, split_images\short_story-049_middle.png, and split_images\short_story-049_bottom.png.
# Image short_story-050.png split and saved as split_images\short_story-050_top.png, split_images\short_story-050_middle.png, and split_images\short_story-050_bottom.png.
# Image short_story-051.png split and saved as split_images\short_story-051_top.png, split_images\short_story-051_middle.png, and split_images\short_story-051_bottom.png.
# Image short_story-052.png split and saved as split_images\short_story-052_top.png, split_images\short_story-052_middle.png, and split_images\short_story-052_bottom.png.
# Image short_story-053.png split and saved as split_images\short_story-053_top.png, split_images\short_story-053_middle.png, and split_images\short_story-053_bottom.png.
# Image short_story-054.png split and saved as split_images\short_story-054_top.png, split_images\short_story-054_middle.png, and split_images\short_story-054_bottom.png.
# Image short_story-055.png split and saved as split_images\short_story-055_top.png, split_images\short_story-055_middle.png, and split_images\short_story-055_bottom.png.
# Image short_story-056.png split and saved as split_images\short_story-056_top.png, split_images\short_story-056_middle.png, and split_images\short_story-056_bottom.png.
# Image short_story-057.png split and saved as split_images\short_story-057_top.png, split_images\short_story-057_middle.png, and split_images\short_story-057_bottom.png.
# Image short_story-058.png split and saved as split_images\short_story-058_top.png, split_images\short_story-058_middle.png, and split_images\short_story-058_bottom.png.
# Image short_story-059.png split and saved as split_images\short_story-059_top.png, split_images\short_story-059_middle.png, and split_images\short_story-059_bottom.png.
# Image short_story-060.png split and saved as split_images\short_story-060_top.png, split_images\short_story-060_middle.png, and split_images\short_story-060_bottom.png.
# Image short_story-061.png split and saved as split_images\short_story-061_top.png, split_images\short_story-061_middle.png, and split_images\short_story-061_bottom.png.
# Image short_story-062.png split and saved as split_images\short_story-062_top.png, split_images\short_story-062_middle.png, and split_images\short_story-062_bottom.png.
# Image short_story-063.png split and saved as split_images\short_story-063_top.png, split_images\short_story-063_middle.png, and split_images\short_story-063_bottom.png.
# Image short_story-064.png split and saved as split_images\short_story-064_top.png, split_images\short_story-064_middle.png, and split_images\short_story-064_bottom.png.
# Image short_story-065.png split and saved as split_images\short_story-065_top.png, split_images\short_story-065_middle.png, and split_images\short_story-065_bottom.png.
# Image short_story-066.png split and saved as split_images\short_story-066_top.png, split_images\short_story-066_middle.png, and split_images\short_story-066_bottom.png.
# Image short_story-067.png split and saved as split_images\short_story-067_top.png, split_images\short_story-067_middle.png, and split_images\short_story-067_bottom.png.
# Image short_story-068.png split and saved as split_images\short_story-068_top.png, split_images\short_story-068_middle.png, and split_images\short_story-068_bottom.png.
# Image short_story-069.png split and saved as split_images\short_story-069_top.png, split_images\short_story-069_middle.png, and split_images\short_story-069_bottom.png.
# Image short_story-070.png split and saved as split_images\short_story-070_top.png, split_images\short_story-070_middle.png, and split_images\short_story-070_bottom.png.
# Image short_story-071.png split and saved as split_images\short_story-071_top.png, split_images\short_story-071_middle.png, and split_images\short_story-071_bottom.png.
# Image short_story-072.png split and saved as split_images\short_story-072_top.png, split_images\short_story-072_middle.png, and split_images\short_story-072_bottom.png.
# Image short_story-073.png split and saved as split_images\short_story-073_top.png, split_images\short_story-073_middle.png, and split_images\short_story-073_bottom.png.
# Image short_story-074.png split and saved as split_images\short_story-074_top.png, split_images\short_story-074_middle.png, and split_images\short_story-074_bottom.png.
# Image short_story-075.png split and saved as split_images\short_story-075_top.png, split_images\short_story-075_middle.png, and split_images\short_story-075_bottom.png.
# Image short_story-076.png split and saved as split_images\short_story-076_top.png, split_images\short_story-076_middle.png, and split_images\short_story-076_bottom.png.
# Image short_story-077.png split and saved as split_images\short_story-077_top.png, split_images\short_story-077_middle.png, and split_images\short_story-077_bottom.png.
# Image short_story-078.png split and saved as split_images\short_story-078_top.png, split_images\short_story-078_middle.png, and split_images\short_story-078_bottom.png.
# Image short_story-079.png split and saved as split_images\short_story-079_top.png, split_images\short_story-079_middle.png, and split_images\short_story-079_bottom.png.
# Image short_story-080.png split and saved as split_images\short_story-080_top.png, split_images\short_story-080_middle.png, and split_images\short_story-080_bottom.png.
# Image short_story-081.png split and saved as split_images\short_story-081_top.png, split_images\short_story-081_middle.png, and split_images\short_story-081_bottom.png.
# Image short_story-082.png split and saved as split_images\short_story-082_top.png, split_images\short_story-082_middle.png, and split_images\short_story-082_bottom.png.
# Image short_story-083.png split and saved as split_images\short_story-083_top.png, split_images\short_story-083_middle.png, and split_images\short_story-083_bottom.png.
# Image short_story-084.png split and saved as split_images\short_story-084_top.png, split_images\short_story-084_middle.png, and split_images\short_story-084_bottom.png.
# Image short_story-085.png split and saved as split_images\short_story-085_top.png, split_images\short_story-085_middle.png, and split_images\short_story-085_bottom.png.
# Image short_story-086.png split and saved as split_images\short_story-086_top.png, split_images\short_story-086_middle.png, and split_images\short_story-086_bottom.png.
# Image short_story-087.png split and saved as split_images\short_story-087_top.png, split_images\short_story-087_middle.png, and split_images\short_story-087_bottom.png.
# Image short_story-088.png split and saved as split_images\short_story-088_top.png, split_images\short_story-088_middle.png, and split_images\short_story-088_bottom.png.
# Image short_story-089.png split and saved as split_images\short_story-089_top.png, split_images\short_story-089_middle.png, and split_images\short_story-089_bottom.png.
# Image short_story-090.png split and saved as split_images\short_story-090_top.png, split_images\short_story-090_middle.png, and split_images\short_story-090_bottom.png.
# Image short_story-091.png split and saved as split_images\short_story-091_top.png, split_images\short_story-091_middle.png, and split_images\short_story-091_bottom.png.
# Image short_story-092.png split and saved as split_images\short_story-092_top.png, split_images\short_story-092_middle.png, and split_images\short_story-092_bottom.png.
# Image short_story-093.png split and saved as split_images\short_story-093_top.png, split_images\short_story-093_middle.png, and split_images\short_story-093_bottom.png.
# Image short_story-094.png split and saved as split_images\short_story-094_top.png, split_images\short_story-094_middle.png, and split_images\short_story-094_bottom.png.
# Image short_story-095.png split and saved as split_images\short_story-095_top.png, split_images\short_story-095_middle.png, and split_images\short_story-095_bottom.png.
# Image short_story-096.png split and saved as split_images\short_story-096_top.png, split_images\short_story-096_middle.png, and split_images\short_story-096_bottom.png.
# Image short_story-097.png split and saved as split_images\short_story-097_top.png, split_images\short_story-097_middle.png, and split_images\short_story-097_bottom.png.
# Image short_story-098.png split and saved as split_images\short_story-098_top.png, split_images\short_story-098_middle.png, and split_images\short_story-098_bottom.png.
# Image short_story-099.png split and saved as split_images\short_story-099_top.png, split_images\short_story-099_middle.png, and split_images\short_story-099_bottom.png.
# Image short_story-100.png split and saved as split_images\short_story-100_top.png, split_images\short_story-100_middle.png, and split_images\short_story-100_bottom.png.
# Image short_story-101.png split and saved as split_images\short_story-101_top.png, split_images\short_story-101_middle.png, and split_images\short_story-101_bottom.png.
# Image short_story-102.png split and saved as split_images\short_story-102_top.png, split_images\short_story-102_middle.png, and split_images\short_story-102_bottom.png.
# Error: Could not find enough split points for short_story-103.png.
# Image short_story-104.png split and saved as split_images\short_story-104_top.png, split_images\short_story-104_middle.png, and split_images\short_story-104_bottom.png.
# Image short_story-105.png split and saved as split_images\short_story-105_top.png, split_images\short_story-105_middle.png, and split_images\short_story-105_bottom.png.
# Image short_story-106.png split and saved as split_images\short_story-106_top.png, split_images\short_story-106_middle.png, and split_images\short_story-106_bottom.png.
# Image short_story-107.png split and saved as split_images\short_story-107_top.png, split_images\short_story-107_middle.png, and split_images\short_story-107_bottom.png.
# Image short_story-108.png split and saved as split_images\short_story-108_top.png, split_images\short_story-108_middle.png, and split_images\short_story-108_bottom.png.
# Image short_story-109.png split and saved as split_images\short_story-109_top.png, split_images\short_story-109_middle.png, and split_images\short_story-109_bottom.png.
# Image short_story-110.png split and saved as split_images\short_story-110_top.png, split_images\short_story-110_middle.png, and split_images\short_story-110_bottom.png.
# Image short_story-111.png split and saved as split_images\short_story-111_top.png, split_images\short_story-111_middle.png, and split_images\short_story-111_bottom.png.
# Image short_story-112.png split and saved as split_images\short_story-112_top.png, split_images\short_story-112_middle.png, and split_images\short_story-112_bottom.png.
# Image short_story-113.png split and saved as split_images\short_story-113_top.png, split_images\short_story-113_middle.png, and split_images\short_story-113_bottom.png.
# Image short_story-114.png split and saved as split_images\short_story-114_top.png, split_images\short_story-114_middle.png, and split_images\short_story-114_bottom.png.
# Image short_story-115.png split and saved as split_images\short_story-115_top.png, split_images\short_story-115_middle.png, and split_images\short_story-115_bottom.png.
# Image short_story-116.png split and saved as split_images\short_story-116_top.png, split_images\short_story-116_middle.png, and split_images\short_story-116_bottom.png.
# Image short_story-117.png split and saved as split_images\short_story-117_top.png, split_images\short_story-117_middle.png, and split_images\short_story-117_bottom.png.
# Image short_story-118.png split and saved as split_images\short_story-118_top.png, split_images\short_story-118_middle.png, and split_images\short_story-118_bottom.png.
# Image short_story-119.png split and saved as split_images\short_story-119_top.png, split_images\short_story-119_middle.png, and split_images\short_story-119_bottom.png.
# Image short_story-120.png split and saved as split_images\short_story-120_top.png, split_images\short_story-120_middle.png, and split_images\short_story-120_bottom.png.
# Image short_story-121.png split and saved as split_images\short_story-121_top.png, split_images\short_story-121_middle.png, and split_images\short_story-121_bottom.png.
# Image short_story-122.png split and saved as split_images\short_story-122_top.png, split_images\short_story-122_middle.png, and split_images\short_story-122_bottom.png.
# Image short_story-123.png split and saved as split_images\short_story-123_top.png, split_images\short_story-123_middle.png, and split_images\short_story-123_bottom.png.
# Image short_story-124.png split and saved as split_images\short_story-124_top.png, split_images\short_story-124_middle.png, and split_images\short_story-124_bottom.png.
# Image short_story-125.png split and saved as split_images\short_story-125_top.png, split_images\short_story-125_middle.png, and split_images\short_story-125_bottom.png.
# Image short_story-126.png split and saved as split_images\short_story-126_top.png, split_images\short_story-126_middle.png, and split_images\short_story-126_bottom.png.
# Image short_story-127.png split and saved as split_images\short_story-127_top.png, split_images\short_story-127_middle.png, and split_images\short_story-127_bottom.png.
# Image short_story-128.png split and saved as split_images\short_story-128_top.png, split_images\short_story-128_middle.png, and split_images\short_story-128_bottom.png.
# Image short_story-129.png split and saved as split_images\short_story-129_top.png, split_images\short_story-129_middle.png, and split_images\short_story-129_bottom.png.
# Error: Could not find enough split points for short_story-130.png.
# Image short_story-131.png split and saved as split_images\short_story-131_top.png, split_images\short_story-131_middle.png, and split_images\short_story-131_bottom.png.
# Image short_story-132.png split and saved as split_images\short_story-132_top.png, split_images\short_story-132_middle.png, and split_images\short_story-132_bottom.png.
# Image short_story-133.png split and saved as split_images\short_story-133_top.png, split_images\short_story-133_middle.png, and split_images\short_story-133_bottom.png.
# Image short_story-134.png split and saved as split_images\short_story-134_top.png, split_images\short_story-134_middle.png, and split_images\short_story-134_bottom.png.
# Image short_story-135.png split and saved as split_images\short_story-135_top.png, split_images\short_story-135_middle.png, and split_images\short_story-135_bottom.png.
# Error: Could not find enough split points for short_story-136.png.

# %% [markdown]
# ## converting images to text

# %%
import os
import pytesseract
from PIL import Image
import re

# Set up the Tesseract executable path (change if necessary)
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

def is_title_candidate(line, previous_line):
    stripped_line = line.strip()
    # Check for numbers, short length, no punctuation at the end, and previous line is empty
    if (len(stripped_line) > 0 and len(stripped_line.split()) <= 5 and
        not re.search(r'\d', stripped_line) and  # Avoid numbers
        not stripped_line.endswith(('.', '؟', '!', ':')) and  # Avoid ending punctuation
        len(previous_line.strip()) == 0):  # Check if the previous line is empty
        return True
    return False

def png_to_txt_with_titles(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(".png"):
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)
            text = pytesseract.image_to_string(img, lang='ara', config='--psm 6z')
            
            processed_lines = []
            lines = text.split('\n')
            for i, line in enumerate(lines):
                if i == 0:
                    previous_line = ""
                else:
                    previous_line = lines[i - 1]
                
                if is_title_candidate(line, previous_line):
                    line = f"<title>{line.strip()}</title>"
                
                processed_lines.append(line.strip())
            
            txt_filename = f"{os.path.splitext(filename)[0]}.txt"
            txt_path = os.path.join(output_folder, txt_filename)
            
            with open(txt_path, 'w', encoding='utf-8') as f:
                f.write('\n'.join(processed_lines))
            
            print(f"Processed {filename} -> {txt_filename}")

# Example usage
input_folder = r"split_images"
output_folder = r"txtoutput"

png_to_txt_with_titles(input_folder, output_folder)
# Out:
# Processed short_story-003_bottom.png -> short_story-003_bottom.txt
# Processed short_story-003_middle.png -> short_story-003_middle.txt
# Processed short_story-003_top.png -> short_story-003_top.txt
# Processed short_story-004_bottom.png -> short_story-004_bottom.txt
# Processed short_story-004_middle.png -> short_story-004_middle.txt
# Processed short_story-004_top.png -> short_story-004_top.txt
# Processed short_story-005_bottom.png -> short_story-005_bottom.txt
# Processed short_story-005_middle.png -> short_story-005_middle.txt
# Processed short_story-005_top.png -> short_story-005_top.txt
# Processed short_story-006_bottom.png -> short_story-006_bottom.txt
# Processed short_story-006_middle.png -> short_story-006_middle.txt
# Processed short_story-006_top.png -> short_story-006_top.txt
# Processed short_story-007_bottom.png -> short_story-007_bottom.txt
# Processed short_story-007_middle.png -> short_story-007_middle.txt
# Processed short_story-007_top.png -> short_story-007_top.txt
# Processed short_story-008_bottom.png -> short_story-008_bottom.txt
# Processed short_story-008_middle.png -> short_story-008_middle.txt
# Processed short_story-008_top.png -> short_story-008_top.txt
# Processed short_story-009_bottom.png -> short_story-009_bottom.txt
# Processed short_story-009_middle.png -> short_story-009_middle.txt
# Processed short_story-009_top.png -> short_story-009_top.txt
# Processed short_story-010_bottom.png -> short_story-010_bottom.txt
# Processed short_story-010_middle.png -> short_story-010_middle.txt
# Processed short_story-010_top.png -> short_story-010_top.txt
# Processed short_story-011_bottom.png -> short_story-011_bottom.txt
# Processed short_story-011_middle.png -> short_story-011_middle.txt
# Processed short_story-011_top.png -> short_story-011_top.txt
# Processed short_story-012_bottom.png -> short_story-012_bottom.txt
# Processed short_story-012_middle.png -> short_story-012_middle.txt
# Processed short_story-012_top.png -> short_story-012_top.txt
# Processed short_story-013_bottom.png -> short_story-013_bottom.txt
# Processed short_story-013_middle.png -> short_story-013_middle.txt
# Processed short_story-013_top.png -> short_story-013_top.txt
# Processed short_story-014_bottom.png -> short_story-014_bottom.txt
# Processed short_story-014_middle.png -> short_story-014_middle.txt
# Processed short_story-014_top.png -> short_story-014_top.txt
# Processed short_story-015_bottom.png -> short_story-015_bottom.txt
# Processed short_story-015_middle.png -> short_story-015_middle.txt
# Processed short_story-015_top.png -> short_story-015_top.txt
# Processed short_story-016_bottom.png -> short_story-016_bottom.txt
# Processed short_story-016_middle.png -> short_story-016_middle.txt
# Processed short_story-016_top.png -> short_story-016_top.txt
# Processed short_story-017_bottom.png -> short_story-017_bottom.txt
# Processed short_story-017_middle.png -> short_story-017_middle.txt
# Processed short_story-017_top.png -> short_story-017_top.txt
# Processed short_story-018_bottom.png -> short_story-018_bottom.txt
# Processed short_story-018_middle.png -> short_story-018_middle.txt
# Processed short_story-018_top.png -> short_story-018_top.txt
# Processed short_story-019_bottom.png -> short_story-019_bottom.txt
# Processed short_story-019_middle.png -> short_story-019_middle.txt
# Processed short_story-019_top.png -> short_story-019_top.txt
# Processed short_story-020_bottom.png -> short_story-020_bottom.txt
# Processed short_story-020_middle.png -> short_story-020_middle.txt
# Processed short_story-020_top.png -> short_story-020_top.txt
# Processed short_story-021_bottom.png -> short_story-021_bottom.txt
# Processed short_story-021_middle.png -> short_story-021_middle.txt
# Processed short_story-021_top.png -> short_story-021_top.txt
# Processed short_story-022_bottom.png -> short_story-022_bottom.txt
# Processed short_story-022_middle.png -> short_story-022_middle.txt
# Processed short_story-022_top.png -> short_story-022_top.txt
# Processed short_story-023_bottom.png -> short_story-023_bottom.txt
# Processed short_story-023_middle.png -> short_story-023_middle.txt
# Processed short_story-023_top.png -> short_story-023_top.txt
# Processed short_story-024_bottom.png -> short_story-024_bottom.txt
# Processed short_story-024_middle.png -> short_story-024_middle.txt
# Processed short_story-024_top.png -> short_story-024_top.txt
# Processed short_story-025_bottom.png -> short_story-025_bottom.txt
# Processed short_story-025_middle.png -> short_story-025_middle.txt
# Processed short_story-025_top.png -> short_story-025_top.txt
# Processed short_story-026_bottom.png -> short_story-026_bottom.txt
# Processed short_story-026_middle.png -> short_story-026_middle.txt
# Processed short_story-026_top.png -> short_story-026_top.txt
# Processed short_story-027_bottom.png -> short_story-027_bottom.txt
# Processed short_story-027_middle.png -> short_story-027_middle.txt
# Processed short_story-027_top.png -> short_story-027_top.txt
# Processed short_story-028_bottom.png -> short_story-028_bottom.txt
# Processed short_story-028_middle.png -> short_story-028_middle.txt
# Processed short_story-028_top.png -> short_story-028_top.txt
# Processed short_story-029_bottom.png -> short_story-029_bottom.txt
# Processed short_story-029_middle.png -> short_story-029_middle.txt
# Processed short_story-029_top.png -> short_story-029_top.txt
# Processed short_story-030_bottom.png -> short_story-030_bottom.txt
# Processed short_story-030_middle.png -> short_story-030_middle.txt
# Processed short_story-030_top.png -> short_story-030_top.txt
# Processed short_story-031_bottom.png -> short_story-031_bottom.txt
# Processed short_story-031_middle.png -> short_story-031_middle.txt
# Processed short_story-031_top.png -> short_story-031_top.txt
# Processed short_story-032_bottom.png -> short_story-032_bottom.txt
# Processed short_story-032_middle.png -> short_story-032_middle.txt
# Processed short_story-032_top.png -> short_story-032_top.txt
# Processed short_story-033_bottom.png -> short_story-033_bottom.txt
# Processed short_story-033_middle.png -> short_story-033_middle.txt
# Processed short_story-033_top.png -> short_story-033_top.txt
# Processed short_story-034_bottom.png -> short_story-034_bottom.txt
# Processed short_story-034_middle.png -> short_story-034_middle.txt
# Processed short_story-034_top.png -> short_story-034_top.txt
# Processed short_story-035_bottom.png -> short_story-035_bottom.txt
# Processed short_story-035_middle.png -> short_story-035_middle.txt
# Processed short_story-035_top.png -> short_story-035_top.txt
# Processed short_story-036_bottom.png -> short_story-036_bottom.txt
# Processed short_story-036_middle.png -> short_story-036_middle.txt
# Processed short_story-036_top.png -> short_story-036_top.txt
# Processed short_story-037_bottom.png -> short_story-037_bottom.txt
# Processed short_story-037_middle.png -> short_story-037_middle.txt
# Processed short_story-037_top.png -> short_story-037_top.txt
# Processed short_story-038_bottom.png -> short_story-038_bottom.txt
# Processed short_story-038_middle.png -> short_story-038_middle.txt
# Processed short_story-038_top.png -> short_story-038_top.txt
# Processed short_story-039_bottom.png -> short_story-039_bottom.txt
# Processed short_story-039_middle.png -> short_story-039_middle.txt
# Processed short_story-039_top.png -> short_story-039_top.txt
# Processed short_story-040_bottom.png -> short_story-040_bottom.txt
# Processed short_story-040_middle.png -> short_story-040_middle.txt
# Processed short_story-040_top.png -> short_story-040_top.txt
# Processed short_story-041_bottom.png -> short_story-041_bottom.txt
# Processed short_story-041_middle.png -> short_story-041_middle.txt
# Processed short_story-041_top.png -> short_story-041_top.txt
# Processed short_story-042_bottom.png -> short_story-042_bottom.txt
# Processed short_story-042_middle.png -> short_story-042_middle.txt
# Processed short_story-042_top.png -> short_story-042_top.txt
# Processed short_story-043_bottom.png -> short_story-043_bottom.txt
# Processed short_story-043_middle.png -> short_story-043_middle.txt
# Processed short_story-043_top.png -> short_story-043_top.txt
# Processed short_story-044_bottom.png -> short_story-044_bottom.txt
# Processed short_story-044_middle.png -> short_story-044_middle.txt
# Processed short_story-044_top.png -> short_story-044_top.txt
# Processed short_story-045_bottom.png -> short_story-045_bottom.txt
# Processed short_story-045_middle.png -> short_story-045_middle.txt
# Processed short_story-045_top.png -> short_story-045_top.txt
# Processed short_story-046_bottom.png -> short_story-046_bottom.txt
# Processed short_story-046_middle.png -> short_story-046_middle.txt
# Processed short_story-046_top.png -> short_story-046_top.txt
# Processed short_story-047_bottom.png -> short_story-047_bottom.txt
# Processed short_story-047_middle.png -> short_story-047_middle.txt
# Processed short_story-047_top.png -> short_story-047_top.txt
# Processed short_story-048_bottom.png -> short_story-048_bottom.txt
# Processed short_story-048_middle.png -> short_story-048_middle.txt
# Processed short_story-048_top.png -> short_story-048_top.txt
# Processed short_story-049_bottom.png -> short_story-049_bottom.txt
# Processed short_story-049_middle.png -> short_story-049_middle.txt
# Processed short_story-049_top.png -> short_story-049_top.txt
# Processed short_story-050_bottom.png -> short_story-050_bottom.txt
# Processed short_story-050_middle.png -> short_story-050_middle.txt
# Processed short_story-050_top.png -> short_story-050_top.txt
# Processed short_story-051_bottom.png -> short_story-051_bottom.txt
# Processed short_story-051_middle.png -> short_story-051_middle.txt
# Processed short_story-051_top.png -> short_story-051_top.txt
# Processed short_story-052_bottom.png -> short_story-052_bottom.txt
# Processed short_story-052_middle.png -> short_story-052_middle.txt
# Processed short_story-052_top.png -> short_story-052_top.txt
# Processed short_story-053_bottom.png -> short_story-053_bottom.txt
# Processed short_story-053_middle.png -> short_story-053_middle.txt
# Processed short_story-053_top.png -> short_story-053_top.txt
# Processed short_story-054_bottom.png -> short_story-054_bottom.txt
# Processed short_story-054_middle.png -> short_story-054_middle.txt
# Processed short_story-054_top.png -> short_story-054_top.txt
# Processed short_story-055_bottom.png -> short_story-055_bottom.txt
# Processed short_story-055_middle.png -> short_story-055_middle.txt
# Processed short_story-055_top.png -> short_story-055_top.txt
# Processed short_story-056_bottom.png -> short_story-056_bottom.txt
# Processed short_story-056_middle.png -> short_story-056_middle.txt
# Processed short_story-056_top.png -> short_story-056_top.txt
# Processed short_story-057_bottom.png -> short_story-057_bottom.txt
# Processed short_story-057_middle.png -> short_story-057_middle.txt
# Processed short_story-057_top.png -> short_story-057_top.txt
# Processed short_story-058_bottom.png -> short_story-058_bottom.txt
# Processed short_story-058_middle.png -> short_story-058_middle.txt
# Processed short_story-058_top.png -> short_story-058_top.txt
# Processed short_story-059_bottom.png -> short_story-059_bottom.txt
# Processed short_story-059_middle.png -> short_story-059_middle.txt
# Processed short_story-059_top.png -> short_story-059_top.txt
# Processed short_story-060_bottom.png -> short_story-060_bottom.txt
# Processed short_story-060_middle.png -> short_story-060_middle.txt
# Processed short_story-060_top.png -> short_story-060_top.txt
# Processed short_story-061_bottom.png -> short_story-061_bottom.txt
# Processed short_story-061_middle.png -> short_story-061_middle.txt
# Processed short_story-061_top.png -> short_story-061_top.txt
# Processed short_story-062_bottom.png -> short_story-062_bottom.txt
# Processed short_story-062_middle.png -> short_story-062_middle.txt
# Processed short_story-062_top.png -> short_story-062_top.txt
# Processed short_story-063_bottom.png -> short_story-063_bottom.txt
# Processed short_story-063_middle.png -> short_story-063_middle.txt
# Processed short_story-063_top.png -> short_story-063_top.txt
# Processed short_story-064_bottom.png -> short_story-064_bottom.txt
# Processed short_story-064_middle.png -> short_story-064_middle.txt
# Processed short_story-064_top.png -> short_story-064_top.txt
# Processed short_story-065_bottom.png -> short_story-065_bottom.txt
# Processed short_story-065_middle.png -> short_story-065_middle.txt
# Processed short_story-065_top.png -> short_story-065_top.txt
# Processed short_story-066_bottom.png -> short_story-066_bottom.txt
# Processed short_story-066_middle.png -> short_story-066_middle.txt
# Processed short_story-066_top.png -> short_story-066_top.txt
# Processed short_story-067_bottom.png -> short_story-067_bottom.txt
# Processed short_story-067_middle.png -> short_story-067_middle.txt
# Processed short_story-067_top.png -> short_story-067_top.txt
# Processed short_story-068_bottom.png -> short_story-068_bottom.txt
# Processed short_story-068_middle.png -> short_story-068_middle.txt
# Processed short_story-068_top.png -> short_story-068_top.txt
# Processed short_story-069_bottom.png -> short_story-069_bottom.txt
# Processed short_story-069_middle.png -> short_story-069_middle.txt
# Processed short_story-069_top.png -> short_story-069_top.txt
# Processed short_story-070_bottom.png -> short_story-070_bottom.txt
# Processed short_story-070_middle.png -> short_story-070_middle.txt
# Processed short_story-070_top.png -> short_story-070_top.txt
# Processed short_story-071_bottom.png -> short_story-071_bottom.txt
# Processed short_story-071_middle.png -> short_story-071_middle.txt
# Processed short_story-071_top.png -> short_story-071_top.txt
# Processed short_story-072_bottom.png -> short_story-072_bottom.txt
# Processed short_story-072_middle.png -> short_story-072_middle.txt
# Processed short_story-072_top.png -> short_story-072_top.txt
# Processed short_story-073_bottom.png -> short_story-073_bottom.txt
# Processed short_story-073_middle.png -> short_story-073_middle.txt
# Processed short_story-073_top.png -> short_story-073_top.txt
# Processed short_story-074_bottom.png -> short_story-074_bottom.txt
# Processed short_story-074_middle.png -> short_story-074_middle.txt
# Processed short_story-074_top.png -> short_story-074_top.txt
# Processed short_story-075_bottom.png -> short_story-075_bottom.txt
# Processed short_story-075_middle.png -> short_story-075_middle.txt
# Processed short_story-075_top.png -> short_story-075_top.txt
# Processed short_story-076_bottom.png -> short_story-076_bottom.txt
# Processed short_story-076_middle.png -> short_story-076_middle.txt
# Processed short_story-076_top.png -> short_story-076_top.txt
# Processed short_story-077_bottom.png -> short_story-077_bottom.txt
# Processed short_story-077_middle.png -> short_story-077_middle.txt
# Processed short_story-077_top.png -> short_story-077_top.txt
# Processed short_story-078_bottom.png -> short_story-078_bottom.txt
# Processed short_story-078_middle.png -> short_story-078_middle.txt
# Processed short_story-078_top.png -> short_story-078_top.txt
# Processed short_story-079_bottom.png -> short_story-079_bottom.txt
# Processed short_story-079_middle.png -> short_story-079_middle.txt
# Processed short_story-079_top.png -> short_story-079_top.txt
# Processed short_story-080_bottom.png -> short_story-080_bottom.txt
# Processed short_story-080_middle.png -> short_story-080_middle.txt
# Processed short_story-080_top.png -> short_story-080_top.txt
# Processed short_story-081_bottom.png -> short_story-081_bottom.txt
# Processed short_story-081_middle.png -> short_story-081_middle.txt
# Processed short_story-081_top.png -> short_story-081_top.txt
# Processed short_story-082_bottom.png -> short_story-082_bottom.txt
# Processed short_story-082_middle.png -> short_story-082_middle.txt
# Processed short_story-082_top.png -> short_story-082_top.txt
# Processed short_story-083_bottom.png -> short_story-083_bottom.txt
# Processed short_story-083_middle.png -> short_story-083_middle.txt
# Processed short_story-083_top.png -> short_story-083_top.txt
# Processed short_story-084_bottom.png -> short_story-084_bottom.txt
# Processed short_story-084_middle.png -> short_story-084_middle.txt
# Processed short_story-084_top.png -> short_story-084_top.txt
# Processed short_story-085_bottom.png -> short_story-085_bottom.txt
# Processed short_story-085_middle.png -> short_story-085_middle.txt
# Processed short_story-085_top.png -> short_story-085_top.txt
# Processed short_story-086_bottom.png -> short_story-086_bottom.txt
# Processed short_story-086_middle.png -> short_story-086_middle.txt
# Processed short_story-086_top.png -> short_story-086_top.txt
# Processed short_story-087_bottom.png -> short_story-087_bottom.txt
# Processed short_story-087_middle.png -> short_story-087_middle.txt
# Processed short_story-087_top.png -> short_story-087_top.txt
# Processed short_story-088_bottom.png -> short_story-088_bottom.txt
# Processed short_story-088_middle.png -> short_story-088_middle.txt
# Processed short_story-088_top.png -> short_story-088_top.txt
# Processed short_story-089_bottom.png -> short_story-089_bottom.txt
# Processed short_story-089_middle.png -> short_story-089_middle.txt
# Processed short_story-089_top.png -> short_story-089_top.txt
# Processed short_story-090_bottom.png -> short_story-090_bottom.txt
# Processed short_story-090_middle.png -> short_story-090_middle.txt
# Processed short_story-090_top.png -> short_story-090_top.txt
# Processed short_story-091_bottom.png -> short_story-091_bottom.txt
# Processed short_story-091_middle.png -> short_story-091_middle.txt
# Processed short_story-091_top.png -> short_story-091_top.txt
# Processed short_story-092_bottom.png -> short_story-092_bottom.txt
# Processed short_story-092_middle.png -> short_story-092_middle.txt
# Processed short_story-092_top.png -> short_story-092_top.txt
# Processed short_story-093_bottom.png -> short_story-093_bottom.txt
# Processed short_story-093_middle.png -> short_story-093_middle.txt
# Processed short_story-093_top.png -> short_story-093_top.txt
# Processed short_story-094_bottom.png -> short_story-094_bottom.txt
# Processed short_story-094_middle.png -> short_story-094_middle.txt
# Processed short_story-094_top.png -> short_story-094_top.txt
# Processed short_story-095_bottom.png -> short_story-095_bottom.txt
# Processed short_story-095_middle.png -> short_story-095_middle.txt
# Processed short_story-095_top.png -> short_story-095_top.txt
# Processed short_story-096_bottom.png -> short_story-096_bottom.txt
# Processed short_story-096_middle.png -> short_story-096_middle.txt
# Processed short_story-096_top.png -> short_story-096_top.txt
# Processed short_story-097_bottom.png -> short_story-097_bottom.txt
# Processed short_story-097_middle.png -> short_story-097_middle.txt
# Processed short_story-097_top.png -> short_story-097_top.txt
# Processed short_story-098_bottom.png -> short_story-098_bottom.txt
# Processed short_story-098_middle.png -> short_story-098_middle.txt
# Processed short_story-098_top.png -> short_story-098_top.txt
# Processed short_story-099_bottom.png -> short_story-099_bottom.txt
# Processed short_story-099_middle.png -> short_story-099_middle.txt
# Processed short_story-099_top.png -> short_story-099_top.txt
# Processed short_story-100_bottom.png -> short_story-100_bottom.txt
# Processed short_story-100_middle.png -> short_story-100_middle.txt
# Processed short_story-100_top.png -> short_story-100_top.txt
# Processed short_story-101_bottom.png -> short_story-101_bottom.txt
# Processed short_story-101_middle.png -> short_story-101_middle.txt
# Processed short_story-101_top.png -> short_story-101_top.txt
# Processed short_story-102_bottom.png -> short_story-102_bottom.txt
# Processed short_story-102_middle.png -> short_story-102_middle.txt
# Processed short_story-102_top.png -> short_story-102_top.txt
# Processed short_story-104_bottom.png -> short_story-104_bottom.txt
# Processed short_story-104_middle.png -> short_story-104_middle.txt
# Processed short_story-104_top.png -> short_story-104_top.txt
# Processed short_story-105_bottom.png -> short_story-105_bottom.txt
# Processed short_story-105_middle.png -> short_story-105_middle.txt
# Processed short_story-105_top.png -> short_story-105_top.txt
# Processed short_story-106_bottom.png -> short_story-106_bottom.txt
# Processed short_story-106_middle.png -> short_story-106_middle.txt
# Processed short_story-106_top.png -> short_story-106_top.txt
# Processed short_story-107_bottom.png -> short_story-107_bottom.txt
# Processed short_story-107_middle.png -> short_story-107_middle.txt
# Processed short_story-107_top.png -> short_story-107_top.txt
# Processed short_story-108_bottom.png -> short_story-108_bottom.txt
# Processed short_story-108_middle.png -> short_story-108_middle.txt
# Processed short_story-108_top.png -> short_story-108_top.txt
# Processed short_story-109_bottom.png -> short_story-109_bottom.txt
# Processed short_story-109_middle.png -> short_story-109_middle.txt
# Processed short_story-109_top.png -> short_story-109_top.txt
# Processed short_story-110_bottom.png -> short_story-110_bottom.txt
# Processed short_story-110_middle.png -> short_story-110_middle.txt
# Processed short_story-110_top.png -> short_story-110_top.txt
# Processed short_story-111_bottom.png -> short_story-111_bottom.txt
# Processed short_story-111_middle.png -> short_story-111_middle.txt
# Processed short_story-111_top.png -> short_story-111_top.txt
# Processed short_story-112_bottom.png -> short_story-112_bottom.txt
# Processed short_story-112_middle.png -> short_story-112_middle.txt
# Processed short_story-112_top.png -> short_story-112_top.txt
# Processed short_story-113_bottom.png -> short_story-113_bottom.txt
# Processed short_story-113_middle.png -> short_story-113_middle.txt
# Processed short_story-113_top.png -> short_story-113_top.txt
# Processed short_story-114_bottom.png -> short_story-114_bottom.txt
# Processed short_story-114_middle.png -> short_story-114_middle.txt
# Processed short_story-114_top.png -> short_story-114_top.txt
# Processed short_story-115_bottom.png -> short_story-115_bottom.txt
# Processed short_story-115_middle.png -> short_story-115_middle.txt
# Processed short_story-115_top.png -> short_story-115_top.txt
# Processed short_story-116_bottom.png -> short_story-116_bottom.txt
# Processed short_story-116_middle.png -> short_story-116_middle.txt
# Processed short_story-116_top.png -> short_story-116_top.txt
# Processed short_story-117_bottom.png -> short_story-117_bottom.txt
# Processed short_story-117_middle.png -> short_story-117_middle.txt
# Processed short_story-117_top.png -> short_story-117_top.txt
# Processed short_story-118_bottom.png -> short_story-118_bottom.txt
# Processed short_story-118_middle.png -> short_story-118_middle.txt
# Processed short_story-118_top.png -> short_story-118_top.txt
# Processed short_story-119_bottom.png -> short_story-119_bottom.txt
# Processed short_story-119_middle.png -> short_story-119_middle.txt
# Processed short_story-119_top.png -> short_story-119_top.txt
# Processed short_story-120_bottom.png -> short_story-120_bottom.txt
# Processed short_story-120_middle.png -> short_story-120_middle.txt
# Processed short_story-120_top.png -> short_story-120_top.txt
# Processed short_story-121_bottom.png -> short_story-121_bottom.txt
# Processed short_story-121_middle.png -> short_story-121_middle.txt
# Processed short_story-121_top.png -> short_story-121_top.txt
# Processed short_story-122_bottom.png -> short_story-122_bottom.txt
# Processed short_story-122_middle.png -> short_story-122_middle.txt
# Processed short_story-122_top.png -> short_story-122_top.txt
# Processed short_story-123_bottom.png -> short_story-123_bottom.txt
# Processed short_story-123_middle.png -> short_story-123_middle.txt
# Processed short_story-123_top.png -> short_story-123_top.txt
# Processed short_story-124_bottom.png -> short_story-124_bottom.txt
# Processed short_story-124_middle.png -> short_story-124_middle.txt
# Processed short_story-124_top.png -> short_story-124_top.txt
# Processed short_story-125_bottom.png -> short_story-125_bottom.txt
# Processed short_story-125_middle.png -> short_story-125_middle.txt
# Processed short_story-125_top.png -> short_story-125_top.txt
# Processed short_story-126_bottom.png -> short_story-126_bottom.txt
# Processed short_story-126_middle.png -> short_story-126_middle.txt
# Processed short_story-126_top.png -> short_story-126_top.txt
# Processed short_story-127_bottom.png -> short_story-127_bottom.txt
# Processed short_story-127_middle.png -> short_story-127_middle.txt
# Processed short_story-127_top.png -> short_story-127_top.txt
# Processed short_story-128_bottom.png -> short_story-128_bottom.txt
# Processed short_story-128_middle.png -> short_story-128_middle.txt
# Processed short_story-128_top.png -> short_story-128_top.txt
# Processed short_story-129_bottom.png -> short_story-129_bottom.txt
# Processed short_story-129_middle.png -> short_story-129_middle.txt
# Processed short_story-129_top.png -> short_story-129_top.txt
# Processed short_story-131_bottom.png -> short_story-131_bottom.txt
# Processed short_story-131_middle.png -> short_story-131_middle.txt
# Processed short_story-131_top.png -> short_story-131_top.txt
# Processed short_story-132_bottom.png -> short_story-132_bottom.txt
# Processed short_story-132_middle.png -> short_story-132_middle.txt
# Processed short_story-132_top.png -> short_story-132_top.txt
# Processed short_story-133_bottom.png -> short_story-133_bottom.txt
# Processed short_story-133_middle.png -> short_story-133_middle.txt
# Processed short_story-133_top.png -> short_story-133_top.txt
# Processed short_story-134_bottom.png -> short_story-134_bottom.txt
# Processed short_story-134_middle.png -> short_story-134_middle.txt
# Processed short_story-134_top.png -> short_story-134_top.txt
# Processed short_story-135_bottom.png -> short_story-135_bottom.txt
# Processed short_story-135_middle.png -> short_story-135_middle.txt
# Processed short_story-135_top.png -> short_story-135_top.txt

# %% [markdown]
# ## combinning all txt file to one file

# %%
import os

def combine_all_txt_files(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # List all text files in the input folder
    text_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.txt')])

    # Create a dictionary to group files by base name
    file_groups = {}
    
    for file in text_files:
        # Assuming the naming convention is like "page1_top.txt", "page1_middle.txt", "page1_bottom.txt"
        base_name = "_".join(file.split("_")[:-1])  # Get the base name without the suffix (top/middle/bottom)
        if base_name not in file_groups:
            file_groups[base_name] = {}
        # Add file to the respective category
        if "top" in file:
            file_groups[base_name]['top'] = file
        elif "middle" in file:
            file_groups[base_name]['middle'] = file
        elif "bottom" in file:
            file_groups[base_name]['bottom'] = file

    # Combine files for each group
    for base_name, files in file_groups.items():
        # Check that we have all three parts (top, middle, bottom)
        if 'top' in files and 'middle' in files and 'bottom' in files:
            output_file = os.path.join(output_folder, f"{base_name}_combined.txt")
            
            with open(output_file, 'w', encoding='utf-8') as output:
                # Write in the order: top, middle, bottom
                for part in ['top', 'middle', 'bottom']:
                    file_path = os.path.join(input_folder, files[part])
                    with open(file_path, 'r', encoding='utf-8') as f:
                        output.write(f.read())
                        output.write("\n\n")  # Add spacing between sections

            print(f"Combined text written to {output_file}")
        else:
            print(f"Skipping incomplete set for {base_name}: {files}")

# Example usage
combine_all_txt_files('txtoutput', 'combined_txtoutput')
# Out:
# Combined text written to combined_txtoutput\short_story-003_combined.txt
# Combined text written to combined_txtoutput\short_story-004_combined.txt
# Combined text written to combined_txtoutput\short_story-005_combined.txt
# Combined text written to combined_txtoutput\short_story-006_combined.txt
# Combined text written to combined_txtoutput\short_story-007_combined.txt
# Combined text written to combined_txtoutput\short_story-008_combined.txt
# Combined text written to combined_txtoutput\short_story-009_combined.txt
# Combined text written to combined_txtoutput\short_story-010_combined.txt
# Combined text written to combined_txtoutput\short_story-011_combined.txt
# Combined text written to combined_txtoutput\short_story-012_combined.txt
# Combined text written to combined_txtoutput\short_story-013_combined.txt
# Combined text written to combined_txtoutput\short_story-014_combined.txt
# Combined text written to combined_txtoutput\short_story-015_combined.txt
# Combined text written to combined_txtoutput\short_story-016_combined.txt
# Combined text written to combined_txtoutput\short_story-017_combined.txt
# Combined text written to combined_txtoutput\short_story-018_combined.txt
# Combined text written to combined_txtoutput\short_story-019_combined.txt
# Combined text written to combined_txtoutput\short_story-020_combined.txt
# Combined text written to combined_txtoutput\short_story-021_combined.txt
# Combined text written to combined_txtoutput\short_story-022_combined.txt
# Combined text written to combined_txtoutput\short_story-023_combined.txt
# Combined text written to combined_txtoutput\short_story-024_combined.txt
# Combined text written to combined_txtoutput\short_story-025_combined.txt
# Combined text written to combined_txtoutput\short_story-026_combined.txt
# Combined text written to combined_txtoutput\short_story-027_combined.txt
# Combined text written to combined_txtoutput\short_story-028_combined.txt
# Combined text written to combined_txtoutput\short_story-029_combined.txt
# Combined text written to combined_txtoutput\short_story-030_combined.txt
# Combined text written to combined_txtoutput\short_story-031_combined.txt
# Combined text written to combined_txtoutput\short_story-032_combined.txt
# Combined text written to combined_txtoutput\short_story-033_combined.txt
# Combined text written to combined_txtoutput\short_story-034_combined.txt
# Combined text written to combined_txtoutput\short_story-035_combined.txt
# Combined text written to combined_txtoutput\short_story-036_combined.txt
# Combined text written to combined_txtoutput\short_story-037_combined.txt
# Combined text written to combined_txtoutput\short_story-038_combined.txt
# Combined text written to combined_txtoutput\short_story-039_combined.txt
# Combined text written to combined_txtoutput\short_story-040_combined.txt
# Combined text written to combined_txtoutput\short_story-041_combined.txt
# Combined text written to combined_txtoutput\short_story-042_combined.txt
# Combined text written to combined_txtoutput\short_story-043_combined.txt
# Combined text written to combined_txtoutput\short_story-044_combined.txt
# Combined text written to combined_txtoutput\short_story-045_combined.txt
# Combined text written to combined_txtoutput\short_story-046_combined.txt
# Combined text written to combined_txtoutput\short_story-047_combined.txt
# Combined text written to combined_txtoutput\short_story-048_combined.txt
# Combined text written to combined_txtoutput\short_story-049_combined.txt
# Combined text written to combined_txtoutput\short_story-050_combined.txt
# Combined text written to combined_txtoutput\short_story-051_combined.txt
# Combined text written to combined_txtoutput\short_story-052_combined.txt
# Combined text written to combined_txtoutput\short_story-053_combined.txt
# Combined text written to combined_txtoutput\short_story-054_combined.txt
# Combined text written to combined_txtoutput\short_story-055_combined.txt
# Combined text written to combined_txtoutput\short_story-056_combined.txt
# Combined text written to combined_txtoutput\short_story-057_combined.txt
# Combined text written to combined_txtoutput\short_story-058_combined.txt
# Combined text written to combined_txtoutput\short_story-059_combined.txt
# Combined text written to combined_txtoutput\short_story-060_combined.txt
# Combined text written to combined_txtoutput\short_story-061_combined.txt
# Combined text written to combined_txtoutput\short_story-062_combined.txt
# Combined text written to combined_txtoutput\short_story-063_combined.txt
# Combined text written to combined_txtoutput\short_story-064_combined.txt
# Combined text written to combined_txtoutput\short_story-065_combined.txt
# Combined text written to combined_txtoutput\short_story-066_combined.txt
# Combined text written to combined_txtoutput\short_story-067_combined.txt
# Combined text written to combined_txtoutput\short_story-068_combined.txt
# Combined text written to combined_txtoutput\short_story-069_combined.txt
# Combined text written to combined_txtoutput\short_story-070_combined.txt
# Combined text written to combined_txtoutput\short_story-071_combined.txt
# Combined text written to combined_txtoutput\short_story-072_combined.txt
# Combined text written to combined_txtoutput\short_story-073_combined.txt
# Combined text written to combined_txtoutput\short_story-074_combined.txt
# Combined text written to combined_txtoutput\short_story-075_combined.txt
# Combined text written to combined_txtoutput\short_story-076_combined.txt
# Combined text written to combined_txtoutput\short_story-077_combined.txt
# Combined text written to combined_txtoutput\short_story-078_combined.txt
# Combined text written to combined_txtoutput\short_story-079_combined.txt
# Combined text written to combined_txtoutput\short_story-080_combined.txt
# Combined text written to combined_txtoutput\short_story-081_combined.txt
# Combined text written to combined_txtoutput\short_story-082_combined.txt
# Combined text written to combined_txtoutput\short_story-083_combined.txt
# Combined text written to combined_txtoutput\short_story-084_combined.txt
# Combined text written to combined_txtoutput\short_story-085_combined.txt
# Combined text written to combined_txtoutput\short_story-086_combined.txt
# Combined text written to combined_txtoutput\short_story-087_combined.txt
# Combined text written to combined_txtoutput\short_story-088_combined.txt
# Combined text written to combined_txtoutput\short_story-089_combined.txt
# Combined text written to combined_txtoutput\short_story-090_combined.txt
# Combined text written to combined_txtoutput\short_story-091_combined.txt
# Combined text written to combined_txtoutput\short_story-092_combined.txt
# Combined text written to combined_txtoutput\short_story-093_combined.txt
# Combined text written to combined_txtoutput\short_story-094_combined.txt
# Combined text written to combined_txtoutput\short_story-095_combined.txt
# Combined text written to combined_txtoutput\short_story-096_combined.txt
# Combined text written to combined_txtoutput\short_story-097_combined.txt
# Combined text written to combined_txtoutput\short_story-098_combined.txt
# Combined text written to combined_txtoutput\short_story-099_combined.txt
# Combined text written to combined_txtoutput\short_story-100_combined.txt
# Combined text written to combined_txtoutput\short_story-101_combined.txt
# Combined text written to combined_txtoutput\short_story-102_combined.txt
# Combined text written to combined_txtoutput\short_story-104_combined.txt
# Combined text written to combined_txtoutput\short_story-105_combined.txt
# Combined text written to combined_txtoutput\short_story-106_combined.txt
# Combined text written to combined_txtoutput\short_story-107_combined.txt
# Combined text written to combined_txtoutput\short_story-108_combined.txt
# Combined text written to combined_txtoutput\short_story-109_combined.txt
# Combined text written to combined_txtoutput\short_story-110_combined.txt
# Combined text written to combined_txtoutput\short_story-111_combined.txt
# Combined text written to combined_txtoutput\short_story-112_combined.txt
# Combined text written to combined_txtoutput\short_story-113_combined.txt
# Combined text written to combined_txtoutput\short_story-114_combined.txt
# Combined text written to combined_txtoutput\short_story-115_combined.txt
# Combined text written to combined_txtoutput\short_story-116_combined.txt
# Combined text written to combined_txtoutput\short_story-117_combined.txt
# Combined text written to combined_txtoutput\short_story-118_combined.txt
# Combined text written to combined_txtoutput\short_story-119_combined.txt
# Combined text written to combined_txtoutput\short_story-120_combined.txt
# Combined text written to combined_txtoutput\short_story-121_combined.txt
# Combined text written to combined_txtoutput\short_story-122_combined.txt
# Combined text written to combined_txtoutput\short_story-123_combined.txt
# Combined text written to combined_txtoutput\short_story-124_combined.txt
# Combined text written to combined_txtoutput\short_story-125_combined.txt
# Combined text written to combined_txtoutput\short_story-126_combined.txt
# Combined text written to combined_txtoutput\short_story-127_combined.txt
# Combined text written to combined_txtoutput\short_story-128_combined.txt
# Combined text written to combined_txtoutput\short_story-129_combined.txt
# Combined text written to combined_txtoutput\short_story-131_combined.txt
# Combined text written to combined_txtoutput\short_story-132_combined.txt
# Combined text written to combined_txtoutput\short_story-133_combined.txt
# Combined text written to combined_txtoutput\short_story-134_combined.txt
# Combined text written to combined_txtoutput\short_story-135_combined.txt

# %% [markdown]
# ## Converting to one docx file

# %%
import os
from collections import defaultdict
from docx import Document
from docx.shared import RGBColor
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

def combine_txt_files_by_prefix_to_word(input_folder, output_folder):
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # List all text files in the input folder
    text_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.txt')])

    # Group files by their prefix (start name)
    file_groups = defaultdict(list)
    for text_file in text_files:
        # Extract prefix (start name) before the first underscore
        prefix = text_file.split('_')[0]
        file_groups[prefix].append(text_file)

    # Process each group of files and combine them into a single document
    for prefix, files in file_groups.items():
        doc = Document()

        # Process each file in the group and add its content to the document
        for text_file in files:
            file_path = os.path.join(input_folder, text_file)

            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    stripped_line = line.strip()

                    # Check if the line is a title
                    if stripped_line.startswith('<title>') and stripped_line.endswith('</title>'):
                        # Extract the title text
                        title_text = stripped_line[7:-8]  # Remove <title> and </title>

                        # Add the title paragraph with centered alignment and color
                        title_paragraph = doc.add_paragraph(title_text)
                        title_paragraph.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER
                        run = title_paragraph.runs[0]
                        run.font.color.rgb = RGBColor(255, 0, 0)  # Change color to red (you can adjust RGB color)

                    else:
                        # Add regular paragraphs
                        doc.add_paragraph(stripped_line)

            # Optionally, add a page break after each file in the group
            doc.add_page_break()

        # Save the combined document for this prefix
        output_file = os.path.join(output_folder, f"{prefix}_combined.docx")
        doc.save(output_file)

        print(f"Combined Word document created: {output_file}")

# Example usage
input_folder = 'combined_txtoutput'  # Folder with text files
output_folder = 'combined_word_output'  # Folder to save combined .docx files

# Call the function
combine_txt_files_by_prefix_to_word(input_folder, output_folder)
# Out:
# Combined Word document created: combined_word_output\short_combined.docx
